# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
import csv
from Line import Artists


client_id="ab6e512f22334140a3d98043b55c4865"
client_secret="7831520fd7d74b04ba8651aae3cba6eb"

disco = Artists("smoloctopus",client_id,client_secret)
disco.sheet #Might take 10-30 seconds to run
# Out:
#                           PlaylistName  Collaborative Playlist  \
# 0     MY chill chords for feelin bored                   False
# 1     MY chill chords for feelin bored                   False
# 2     MY chill chords for feelin bored                   False
# 3     MY chill chords for feelin bored                   False
# 4     MY chill chords for feelin bored                   False
# ...                                ...                     ...
# 3020                            TikTok                   False
# 3021                            TikTok                   False
# 3022                            TikTok                   False
# 3023                            TikTok                   False
# 3024                            TikTok                   False
#
#                          SongName     Added By               Artist Feature1  \
# 0                   Still Beating  smoloctopus          Mac DeMarco      NaN
# ...

# %%
sh= disco.sheet
sh["Added By"].value_counts()

sh["Added By"].unique()

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
        client_id=client_id,
        client_secret=client_secret,
        redirect_uri="http://localhost:8888/callback",
        scope="playlist-read-private"))

sh1 = sh
for i in sh["Added By"].unique():
    user_info = sp.user(str(i))["display_name"]
    sh1["Added By"] = sh1["Added By"].replace(i, user_info)

# %%
sh1["Added By"].value_counts()
# Out:
# Added By
# maddie <3          2851
# guy                  51
# Grady                31
# seanleo26            26
# Alex                 24
# Adam Mancini         16
# DonnyIsHandsome      10
# joe,                  8
# Rohan                 8
# Name: count, dtype: int64
